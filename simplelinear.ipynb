# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/areas_prices.csv")
display(df)
# Out:
#    area   price
# 0   500   50000
# 1   750   75000
# 2  1000  100000
# 3  1250  125000
# 4  1500  150000

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
new_df = df.drop('price',axis='columns')
new_df
# Out:
#    area
# 0   500
# 1   750
# 2  1000
# 3  1250
# 4  1500

# %%
model = linear_model.LinearRegression()
model.fit(df[["area"]], df["price"])
print(df.columns)
# Out:
# Index(['area', 'price'], dtype='object')

# %%
model.predict([[500]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([50000.])

# %%
model.coef_
# Out:
# array([100.])

# %%
model.intercept_
# Out:
# np.float64(0.0)

# %%
100.*500+0.0
# Out:
# 50000.0

# %% [markdown]
# y= mx + b

# %%
areas = pd.read_csv("/content/areas_only.csv")

predicted_price = model.predict(areas[["area"]])   # Use only the area column

areas["predicted_price"] = predicted_price

areas.to_csv("/content/areas_only.csv", index=False)

print(areas)
# Out:
#    area  predicted_price
# 0   600          60000.0
# 1   800          80000.0
# 2  1100         110000.0
# 3  1400         140000.0
# 4  1700         170000.0
